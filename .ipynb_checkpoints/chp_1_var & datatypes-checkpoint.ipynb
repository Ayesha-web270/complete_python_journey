# %%
#print("hey my name is ayesha!")
print("hey my name is ayesha!","i am 22 year olds")
# Out:
# hey my name is ayesha! i am 22 year olds

# %%
print ("i am 22 year olds")
# Out:
# i am 22 year olds

# %%
print(22)
# Out:
# 22

# %%
print(22+35,22*5)
# Out:
# 57 110

# %%
# multiples variables
name = "Ayesha" #string and quotes use for sttring
age = 22 #int
price =25.99 #float
print (name) #double quote print same value but when we need to print value remove quotes
# Out:
# Ayesha

# %%
#another way to display output

name = "Ayesha" #string and quotes use for sttring
age = 22 #int
price =25.99 #float
print("my name is :",name)
print("my age is :", age)
# Out:
# my name is : Ayesha
# my age is : 22

# %%
age2 = age #declaring one variable to the previous one gives the same reslt
print(age)
# Out:
# 22

# %%
print(type(name)) #we use type for knowing data type of variable
print(type(age))   #datatype like int,float,boolean(T,F),"string" '',none
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
age=22      #int
old=False    #boolean
a=None       #none
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
#print sum 
a=23
b=45
sum= a+b
print(sum)
# Out:
# 68

# %%
# hi i am comment 
# lets do 
# it  
#for multi line comment you can simply do ctrl+/

# %%
#OPERATORS
#Arithmetic operators
a=5
b=4
sum=a+b
print(sum)
print(a-b)
print(a*b)
print(a/b) #in python divided value must be in float
print(a%b)   #moduler operator it gives reminder od divisibles
print(a**b)  # to find power
# Out:
# 9
# 1
# 20
# 1.25
# 1
# 625

# %%
#Relational or comparison opeartor
a=79
b=745
#in relational or comparison output would be T,F
print(a==b)
print(a!=b) 
print(a>=b)
# Out:
# False
# True
# False

# %%
#Assignment operators it means assiging values like=
num=45
#num=num+10
num+=10  #+= is assignment there   simply we can do *=, -=, %=
print("num :" ,num)
# Out:
# num : 55

# %%
#logical operator
a=76
b=786
print(not False)
print(not (a>b))
# Out:
# True
# True

# %%
#and operator
val1=True
val2=True
print("ans operator:", val1 and val2)
print("or operator:", (a==b) or (a>b))
# Out:
# ans operator: True
# or operator: False

# %%
#type conversion 2 types 

#type conversion mean automatically python do it for us
#type casting mean manually mean programmer tells python to do this conversion

# %%
#type conversion]
a=57
b=6.45
sum = a+b 
#here in this case float is superior then int python conert it in float automatically
print(sum)
# Out:
# 63.45

# %%
a=int("6") # in this string value 6 convert to int
b=4.65
print(a+b)
print (type(a))
print(type(b))
# Out:
# 10.65
# <class 'int'>
# <class 'float'>

# %%
a=67.6
a=str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
#input (how to take input from user)
name=input("enter your name:")
print("welcom" ,name)
print(type(name)) #input result always in str
# Out:
# enter your name: Ayesha
# welcom Ayesha
# <class 'str'>

# %%
int("25")  #here is type casting of input , here its int float would be same 
val=int(input("enter your age:"))
print(type(val), val)
# Out:
# enter your age: 22
# <class 'int'> 22

# %%
name=input("enter your name:")
age=input("enter your age:")
print("welcom",name)
print("age", age)
# Out:
# enter your name: mahi
# enter your age: 12]
# welcom mahi
# age 12]

# %%
#type casting over previosus cell
name=str(input("enter your name:"))
age=float(input("enter your age:"))
print("welcom",name)
print("age", age)
# Out:
# enter your name: mahi
# enter your age: 12
# welcom mahi
# age 12.0

# %%
#write a program to input 2 numbers and print their sum
first=int(input("enter your first no:"))
second=int(input("enter your second no"))
print("sum =:", first+second)
# Out:
# enter your first no: 543
# enter your second no 5647
# sum =: 6190

# %%
#input side of a square & print its area
side=float(input("side of square:"))
print("area of square:",side*side)
# Out:
# side of square: 65
# area of square: 4225.0

# %%
#input 2 floating point number &print their average
num1=float(input("enter first number:"))
num2=float(input("enter second number:"))
print("Average",num1+num2/2)
# Out:
# enter first number: 43
# enter second number: 654
# Average 370.0

# %%
#input 2 int number a &  b
# print true if a is greater than or equal to b. if not print false

a=float(input("enter first number:"))
b=float(input("enter second number:"))

print(a>=b)
# Out:
# enter first number: 65
# enter second number: 67
# False
